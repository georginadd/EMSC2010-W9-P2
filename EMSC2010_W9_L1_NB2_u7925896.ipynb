# %% [markdown]
# <a href="https://colab.research.google.com/github/georginadd/EMSC2010-W9-P2/blob/main/EMSC2010_W9_L1_NB2_u7925896.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # EMSC2010-W9-L1-NB2
#
# #### The logistic population model:
#
# $x_{\mathrm{next}} = a x_{\mathrm{initial}}(1-x_{\mathrm{initial}})$
#
# where:
# * $x$ is the population size between 0 and 1.
# * $x_{\mathrm{initial}}$ is the current population size
# * $x_{\mathrm{next}}$ is next year's population size
# * $a$ is the ability to reproduce.

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
### Code the logistic population model

# %% [markdown]
# #### The logistic population model with harvesting:
#
# $x_{\mathrm{next}} = a x_{\mathrm{initial}}(1-x_{\mathrm{initial}}) - h$
#
# where:
# * $x$ is the population size between 0 and 1.
# * $x_{\mathrm{initial}}$ is the current population size.
# * $x_{\mathrm{next}}$ is next year's population size.
# * $a$ is the ability to reproduce.
# * $h$ is the size of the harvest between 0 and 1.

# %%
### Code the logistic population model with harvesting

# %% [markdown]
# #### The logistic population model with randomness:
#
# $x_{\mathrm{next}} = (a+r) x_{\mathrm{initial}}(1-x_{\mathrm{initial}})$
#
# where:
# * $x$ is the population size between 0 and 1.
# * $x_{\mathrm{initial}}$ is the current population size.
# * $x_{\mathrm{next}}$ is next year's population size.
# * $a$ is the ability to reproduce.
# * $r$ is a normally distributed random number that changes each year.

# %%
### Code the logistic population model with randomness

# %% [markdown]
# #### The logistic map:
#
# $x_{\mathrm{next}} = a x_{\mathrm{initial}}(1-x_{\mathrm{initial}})$
#
# where:
# * $x$ is the population size between 0 and 1.
# * $x_{\mathrm{initial}}$ is the current population size
# * $x_{\mathrm{next}}$ is next year's population size
# * $a$ is the ability to reproduce.
#
# Follow these steps:
#
# 1. Choose a random value of $a$ from 0 to 4.
#
# 2. Choose a random starting population x_{\mathrm{initial}} from 0 to 1
#
# 3. Run the model for 2,000 generations and record the $x$ value of the last generation.
#
# 4. Repeat steps 1-3 a large number of times (thousands)
#
# 5. Make a scatter plot of $a$ (x-axis) versus final $x$ (y-axis).

# %%
### Code the logistic map
a_out = []
x_out = []
for j in range(20000):
  a = np.random.rand()*0.3+3.8
  a_out.append(a)
  x = np.random.rand()
  for i in range(2000):
    x = a*x*(1-x)
  x_out.append(x)

# %%
plt.plot(a_out, x_out, '.', markersize=0.3)
plt.xlabel('a')
plt.ylabel('x final')
plt.minorticks_on()

# %%
#between 1 & 3, will get the same x final based on the a value, x initial doesn't change the result
#at ~3 bifurcates, shows values of a that it will oscillate between 2 values for
#as we increase a, the diff betwenen the 2 values in the cycle gets bigger, the amplitude increases
#at ~3.6 it bifurcates again, have 4 values
#after that get lots of different values, becomes chaotic, can't clearly predict what's happening
#restrict from 3.3-3.8:
# fractal pattern
#3.8-4.1:
#when around 3.83, only 3 diff values possible, but then get bifurcations again
#at 4 becomes v chaotic, broad range of x final
